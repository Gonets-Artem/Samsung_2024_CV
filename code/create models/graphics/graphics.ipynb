# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Classification glasses

# %%
train_loss = [0.2498, 0.1377, 0.1334, 0.1380, 0.1422, 0.1418, 0.1301, 0.1410, 0.1352, 0.1334]
val_loss = [0.1031, 0.1046, 0.1044, 0.1025, 0.1002, 0.1006, 0.1009, 0.1018, 0.1021, 0.1031]
train_acc = [0.8963, 0.9536, 0.9556, 0.9562, 0.9539, 0.9531, 0.9613, 0.9575, 0.9580, 0.9561]
val_acc = [0.9655, 0.9629, 0.9635, 0.9635, 0.9642, 0.9635, 0.9655, 0.9642, 0.9648, 0.9642]

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(12, 4), layout="constrained")

ax[0].plot(train_loss, label='train_loss')
ax[0].plot(val_loss, label='val_loss')
ax[0].legend()
ax[0].grid(True)

ax[1].plot(train_acc, label='train_acc')
ax[1].plot(val_acc, label='val_acc')
ax[1].legend()
ax[1].grid(True)

plt.savefig('graphics_clas_glas.png')
plt.show()

# %% [markdown]
# ## Segmentation glasses

# %%
train_loss = [0.6564, 0.3794, 0.1389, 0.0682, 0.0486, 0.0396, 0.0351, 0.0322, 0.0301, 0.0280, 0.0267, 0.0253, 0.0245, 0.0233, 
              0.0229, 0.0224, 0.0216, 0.0212, 0.0210, 0.0210, 0.0206, 0.0201, 0.0201, 0.0194, 0.0193, 0.0192, 0.0211, 0.0204, 
              0.0199, 0.0192, 0.0191, 0.0186, 0.0184, 0.0183, 0.0182, 0.0178, 0.0177, 0.0175, 0.0178, 0.0175, 0.0176, 0.0172, 
              0.0165, 0.0164, 0.0163, 0.0163, 0.0163, 0.0162, 0.0161, 0.0161]
val_loss = [0.5400, 0.2732, 0.0941, 0.0552, 0.0439, 0.0365, 0.0334, 0.0289, 0.0308, 0.0268, 0.0243, 0.0231, 0.0225, 0.0217, 
            0.0211, 0.0207, 0.0208, 0.0203, 0.0196, 0.0194, 0.0203, 0.0192, 0.0186, 0.0189, 0.0184, 0.0183, 0.0229, 0.0188, 
            0.0185, 0.0175, 0.0179, 0.0172, 0.0181, 0.0178, 0.0170, 0.0169, 0.0166, 0.0167, 0.0167, 0.0167, 0.0169, 0.0161, 
            0.0160, 0.0159, 0.0158, 0.0158, 0.0159, 0.0157, 0.0157, 0.0157]
train_iou = [0.499, 0.852, 0.922, 0.938, 0.945, 0.950, 0.952, 0.953, 0.954, 0.956, 0.957, 0.958, 0.959, 0.961, 
             0.961, 0.961, 0.962, 0.963, 0.963, 0.963, 0.963, 0.964, 0.963, 0.964, 0.965, 0.965, 0.961, 0.962, 
             0.963, 0.964, 0.964, 0.965, 0.966, 0.966, 0.966, 0.966, 0.967, 0.967, 0.966, 0.967, 0.967, 0.967,
             0.969, 0.969, 0.969, 0.969, 0.969, 0.969, 0.969, 0.969]
val_iou = [0.615, 0.885, 0.937, 0.946, 0.948, 0.951, 0.953, 0.957, 0.952, 0.957, 0.961, 0.962, 0.963, 0.963, 
           0.964, 0.964, 0.964, 0.964, 0.965, 0.965, 0.963, 0.965, 0.966, 0.965, 0.966, 0.967, 0.967, 0.965, 
           0.966, 0.967, 0.967, 0.968, 0.966, 0.967, 0.968, 0.968, 0.969, 0.969, 0.968, 0.968, 0.968, 0.969, 
           0.970, 0.970, 0.970, 0.970, 0.970, 0.970, 0.970, 0.970]

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(12, 4), layout="constrained")

ax[0].plot(train_loss, label='train_loss')
ax[0].plot(val_loss, label='val_loss')
ax[0].legend()
ax[0].grid(True)

ax[1].plot(train_iou, label='train_iou')
ax[1].plot(val_iou, label='val_iou')
ax[1].legend()
ax[1].grid(True)

plt.savefig('graphics_segm_glas.png')
plt.show()

# %% [markdown]
# ## Segmentation people

# %%
train_loss = [0.1971, 0.1131, 0.0930, 0.0893, 0.0843, 0.0810, 0.0728, 0.0768, 0.0623, 0.0530, 
              0.0484, 0.0463, 0.0426, 0.0423, 0.0397, 0.0394, 0.0382, 0.0360, 0.0357, 0.0355, 
              0.0351, 0.0346, 0.0342, 0.0342, 0.0348, 0.0334, 0.0335, 0.0335, 0.0339, 0.0341]
val_loss = [0.1375, 0.1085, 0.0842, 0.0836, 0.0827, 0.0833, 0.0787, 0.0734, 0.0609, 0.0573, 
            0.0551, 0.0515, 0.0508, 0.0510, 0.0496, 0.0479, 0.0478, 0.0475, 0.0479, 0.0478, 
            0.0475, 0.0475, 0.0472, 0.0472, 0.0473, 0.0468, 0.0472, 0.0468, 0.0473, 0.0470]
train_iou = [0.740, 0.807, 0.835, 0.839, 0.847, 0.853, 0.866, 0.859, 0.884, 0.901, 0.909, 0.913, 0.919, 0.920, 0.925, 
             0.925, 0.927, 0.931, 0.932, 0.932, 0.933, 0.934, 0.935, 0.935, 0.934, 0.936, 0.936, 0.936, 0.935, 0.935]
val_iou = [0.777, 0.812, 0.850, 0.849, 0.850, 0.849, 0.856, 0.865, 0.887, 0.893, 0.897, 0.903, 0.905, 0.904, 0.907, 
           0.910, 0.910, 0.911, 0.910, 0.910, 0.911, 0.911, 0.911, 0.911, 0.911, 0.912, 0.911, 0.912, 0.911, 0.911]

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(12, 4), layout="constrained")

ax[0].plot(train_loss, label='train_loss')
ax[0].plot(val_loss, label='val_loss')
ax[0].legend()
ax[0].grid(True)

ax[1].plot(train_iou, label='train_iou')
ax[1].plot(val_iou, label='val_iou')
ax[1].legend()
ax[1].grid(True)

plt.savefig('graphics_segm_peop.png')
plt.show()
